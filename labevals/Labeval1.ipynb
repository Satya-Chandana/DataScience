# %%
import pandas as pd

# %%
#1

df=pd.read_csv('/content/IoTBotNetDataset.csv')
df
# Out:
#        pkSeqID       stime flags  flgs_number proto  proto_number  \
# 0            1  1528088522     e            1   tcp           1.0
# 1            2  1528088522     e            1   arp           2.0
# 2            3  1528088522     e            1   UDP           1.0
# 3            4  1528088522     i            1   tcp           1.0
# 4            5  1528088522     e            1   UDP           1.0
# ...        ...         ...   ...          ...   ...           ...
# 25860    25861  1528081322   e s            2   tcp           1.0
# 25861    25862  1528081322   e s            2   tcp           1.0
# 25862    25863  1528081322   e s            2   tcp           1.0
# 25863    25864  1528081322   e s            2   tcp           1.0
# 25864    25865  1528081322   e s            2   tcp           1.0
#
#                  saddr  sport            daddr  dport  ...  \
# 0      192.168.100.147  49960    192.168.100.7     80  ...
# ...

# %%
#2

df1 = df.drop("sport", axis='columns')
df1
# Out:
#        pkSeqID       stime flags  flgs_number proto  proto_number  \
# 0            1  1528088522     e            1   tcp           1.0
# 1            2  1528088522     e            1   arp           2.0
# 2            3  1528088522     e            1   UDP           1.0
# 3            4  1528088522     i            1   tcp           1.0
# 4            5  1528088522     e            1   UDP           1.0
# ...        ...         ...   ...          ...   ...           ...
# 25860    25861  1528081322   e s            2   tcp           1.0
# 25861    25862  1528081322   e s            2   tcp           1.0
# 25862    25863  1528081322   e s            2   tcp           1.0
# 25863    25864  1528081322   e s            2   tcp           1.0
# 25864    25865  1528081322   e s            2   tcp           1.0
#
#                  saddr            daddr  dport  pkts  ...  AR_P_Proto_P_DstIP  \
# 0      192.168.100.147    192.168.100.7     80     8  ...            1.127040
# ...

# %%
#3

df.dropna()
df
# Out:
#        pkSeqID       stime flags  flgs_number proto  proto_number  \
# 0            1  1528088522     e            1   tcp           1.0
# 1            2  1528088522     e            1   arp           2.0
# 2            3  1528088522     e            1   UDP           1.0
# 3            4  1528088522     i            1   tcp           1.0
# 4            5  1528088522     e            1   UDP           1.0
# ...        ...         ...   ...          ...   ...           ...
# 25860    25861  1528081322   e s            2   tcp           1.0
# 25861    25862  1528081322   e s            2   tcp           1.0
# 25862    25863  1528081322   e s            2   tcp           1.0
# 25863    25864  1528081322   e s            2   tcp           1.0
# 25864    25865  1528081322   e s            2   tcp           1.0
#
#                  saddr  sport            daddr  dport  ...  \
# 0      192.168.100.147  49960    192.168.100.7     80  ...
# ...

# %%
#4

df.boxplot(by ='proto', column =['mean'], grid = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#5

out=df['AR_P_Proto_P_Sport'].corr(df['AR_P_Proto_P_Dport'])
out
# Out:
# 0.9372880255738808

# %%
#6

df.describe()
# Out:
#             pkSeqID         stime   flgs_number  proto_number         sport  \
# count  25865.000000  2.586500e+04  25865.000000  25862.000000  25865.000000
# mean   12933.000000  1.528082e+09      1.946221      1.000309  12523.932534
# std     7466.726692  1.677936e+03      0.229157      0.017586  11021.689836
# min        1.000000  1.528081e+09      1.000000      1.000000     -1.000000
# 25%     6467.000000  1.528081e+09      2.000000      1.000000   5770.000000
# 50%    12933.000000  1.528081e+09      2.000000      1.000000   9316.000000
# 75%    19399.000000  1.528081e+09      2.000000      1.000000  15782.000000
# max    25865.000000  1.528089e+09      4.000000      2.000000  55062.000000
#
#               dport          pkts         bytes  state_number         ltime  \
# count  25865.000000  25865.000000  25865.000000  25865.000000  2.586500e+04
# mean      79.974947      5.213880    801.259540      2.702455  1.528082e+09
# ...

# %%
#7

df.head(3)
# Out:
#    pkSeqID       stime flags  flgs_number proto  proto_number  \
# 0        1  1528088522     e            1   tcp           1.0
# 1        2  1528088522     e            1   arp           2.0
# 2        3  1528088522     e            1   UDP           1.0
#
#              saddr  sport            daddr  dport  ...  AR_P_Proto_P_DstIP  \
# 0  192.168.100.147  49960    192.168.100.7     80  ...             1.12704
# 1    192.168.100.7     -1  192.168.100.147     -1  ...         15267.20000
# 2  192.168.100.147  49962    192.168.100.7     80  ...             1.12704
#
#    N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 0               96.0              75.0            1.133720
# 1                1.0               2.0            0.005142
# 2               96.0              75.0            1.135100
#
#    AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 0            1.129970                             770.0
# 1            0.005142                               2.0
# ...

# %%
#8 

df.tail(4)
# Out:
#        pkSeqID       stime flags  flgs_number proto  proto_number  \
# 25861    25862  1528081322   e s            2   tcp           1.0
# 25862    25863  1528081322   e s            2   tcp           1.0
# 25863    25864  1528081322   e s            2   tcp           1.0
# 25864    25865  1528081322   e s            2   tcp           1.0
#
#                  saddr  sport          daddr  dport  ...  AR_P_Proto_P_DstIP  \
# 25861  192.168.100.148   8693  192.168.100.6     80  ...            0.203495
# 25862  192.168.100.148   8698  192.168.100.6     80  ...            0.203495
# 25863  192.168.100.148   8699  192.168.100.6     80  ...            0.203495
# 25864  192.168.100.148   8702  192.168.100.6     80  ...            0.200000
#
#        N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 25861              100.0             100.0            0.223104
# 25862              100.0             100.0            0.223104
# ...

# %%
#9

df = pd.DataFrame(df)
df.loc[df['proto']=="UDP"].head(1)
# Out:
#    pkSeqID       stime flags  flgs_number proto  proto_number  \
# 2        3  1528088522     e            1   UDP           1.0
#
#              saddr  sport          daddr  dport  ...  AR_P_Proto_P_DstIP  \
# 2  192.168.100.147  49962  192.168.100.7     80  ...             1.12704
#
#    N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 2               96.0              75.0              1.1351
#
#    AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 2             1.12997                             770.0
#
#    Pkts_P_State_P_Protocol_P_SrcIP  attack  category  subcategory
# 2                            602.0     1.0       DoS         HTTP
#
# [1 rows x 46 columns]

# %%
#10
len(df.axes[0])
#df.shape
# Out:
# 25865

# %%
#11

# print(df.iloc[0],5)
print(df.iloc[0 , :5])
# Out:
# pkSeqID                 1
# stime          1528088522
# flags                   e
# flgs_number             1
# proto                 tcp
# Name: 0, dtype: object

# %%
#12 
print("No. of i's =",df['flags'].value_counts()['i'])

df.loc[df["flags"]=='i']["pkts"].sum()
# Out:
# No. of i's = 30
# 240

# %%
#13


df2 = df[df['pkts'] <= 10]
df2


df3 = df[df['pkts']>10]
df3
# Out:
#       pkSeqID       stime flags  flgs_number proto  proto_number  \
# 144       145  1528088522   e s            2   tcp           1.0
# 276       277  1528088522   e s            2   tcp           1.0
# 277       278  1528088522   e s            2   UDP           1.0
# 278       279  1528088522   e s            2   UDP           1.0
# 283       284  1528088524   e s            2   tcp           1.0
# 284       285  1528088524   e s            2   tcp           1.0
# 291       292  1528088525   e s            2   tcp           1.0
# 292       293  1528088525   e s            2   tcp           1.0
# 398       399  1528088529     e            1   tcp           1.0
# 408       409  1528088529     e            1   tcp           1.0
# 415       416  1528088529     e            1   tcp           1.0
# 416       417  1528088529     e            1   tcp           1.0
# 417       418  1528088529     e            1   tcp           1.0
# ...

# %%
#13

x=df.loc[df['stime'] == 1528088522, 'sbytes'].mean()

y=df.loc[df['stime'] == 1528088522,'dbytes' ].mean()

z=df.loc[df['stime'] == 1528088522, 'pkts'].mean()
print(x,y,z)
# Out:
# 792.7923875432526 1001.9480968858131 8.069204152249135

# %%
#14

# %%
#16
import matplotlib.pyplot as plt

x=df["seq"][df["stime"]==1528088522]
plt.hist(x,bins=[0,20,40,60,80,100],label='seq')
plt.legend()
